# %% [markdown]
# # blur all the faces with haarCascade

# %%
import cv2


# to detect the face of the human 

cascade = cv2.CascadeClassifier("./haarcascade_frontalface_default.xml") 

cap = cv2.VideoCapture("")
cap = cv2.VideoCapture(0)


while(True):

# Capture frame-by-frame

    ret, frame = cap.read()

# Display the resulting frame

    
# convert the frame into grayscale(shades of black & white) 

    gray_image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 

    face = cascade.detectMultiScale(gray_image, 

                                scaleFactor=2.0, 

                                minNeighbors=4)
   

    for x, y, w, h in face: 

    # draw a border around the detected face. 

    # (here border color = green, and thickness = 3) 

        image = cv2.rectangle(frame, (x, y), 

                          (x+w, y+h),  

                          (0, 255, 0), 3) 
        
#         image[y:y+h, x:x+w] = cv2.medianBlur(image[y:y+h, x:x+w], 35) 
        image[y:y+h, x:x+w] = cv2.GaussianBlur(image[y:y+h, x:x+w], (99, 99), 30)

    cv2.imshow("preview",frame)

#Waits for a user input to quit the application

    if cv2.waitKey(1) & 0xFF == ord("q"):

        break

# When everything done, release the capture

cap.release()

cv2.destroyAllWindows()

# %% [markdown]
# # blur all the faces with face_recognition

# %%
import face_recognition
import cv2

# Get a reference to webcam #0 (the default one)
video_capture = cv2.VideoCapture(0)



while True:
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Resize frame of video to 1/4 size for faster face detection processing
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

    # Find all the faces and face encodings in the current frame of video
    face_locations = face_recognition.face_locations(small_frame, model="cnn")

    # Display the results
    for top, right, bottom, left in face_locations:
        # Scale back up face locations since the frame we detected in was scaled to 1/4 size
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        # Extract the region of the image that contains the face
        face_image = frame[top:bottom, left:right]
        # Blur the face image
        face_image = cv2.GaussianBlur(face_image, (99, 99), 30)
        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)
        # Put the blurred face region back into the frame image
        frame[top:bottom, left:right] = face_image

    # Display the resulting image
    cv2.imshow('Video', frame)

    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release handle to the webcam
video_capture.release()
cv2.destroyAllWindows()

# %% [markdown]
# #  Blur one face

# %%
import face_recognition 
import cv2

# import images
image = face_recognition.load_image_file("./image_thumb.png")
imageF = face_recognition.load_image_file("./télécharger.jpg")
imageH = face_recognition.load_image_file("./WhatsApp_Image_2022-04-29_at_14.34.06-removebg-preview (2).png")

# encode the image specified
fatyEn = face_recognition.face_encodings(imageF)[0]

#  detect faces and encode it 
face_locations = face_recognition.face_locations(image)
imageEnco = face_recognition.face_encodings(image,face_locations)



# faceMatch =[]
# for faceEn in imageEnco :
#     matches = face_recognition.compare_faces([fatyEn] , faceEn )
#     faceMatch.append(matches)
    
    
name =["faty"]
for (top, right, bottom, left),faceEnco in zip(face_locations,imageEnco) :
    matches = face_recognition.compare_faces([fatyEn] , faceEnco )
    print(matches)
    if matches == [True]:
        cv2.rectangle(image, (left, top), (right, bottom), (0, 50, 255), 2)
        # Draw a label with a name below the face
        cv2.rectangle(image, (left, bottom+30), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(image, name[0], (left + 6, bottom + 20), font, 1.0, (255, 255, 255), 1)
        face_image = image[top:bottom, left:right]
        face_image = cv2.GaussianBlur(face_image, (99, 99), 30)
        image[top:bottom, left:right] = face_image
        
    


cv2.imshow("img" ,image)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-774becf0b928> in <module>
#       5 image = face_recognition.load_image_file("./image_thumb.png")
#       6 imageF = face_recognition.load_image_file("./télécharger.jpg")
# ----> 7 imageH = face_recognition.load_image_file("./WhatsApp_Image_2022-04-29_at_14.34.06-removebg-preview (2).png")
#       8
#       9 # encode the image specified
#
# ~\anaconda3\lib\site-packages\face_recognition\api.py in load_image_file(file, mode)
#      84     :return: image contents as numpy array
#      85     """
# ---> 86     im = PIL.Image.open(file)
#      87     if mode:
#      88         im = im.convert(mode)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
#    2913         exclusive_fp = True
#    2914
#
# FileNotFoundError: [Errno 2] No such file or directory: './WhatsApp_Image_2022-04-29_at_14.34.06-removebg-preview (2).png'
